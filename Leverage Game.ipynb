# %% [markdown]
# <h1> Leverage: The Game </h1>
#
#
# <p>Welcome to Leverage! We believe in helping those who are taken advantage of by the rich and powerful. The game below is based on season 3, episode 12. You can watch this episode on IMDB for free via Prime Video: (https://www.amazon.com/gp/video/detail/amzn1.dv.gti.46a9f702-0830-6c8e-6745-e34a0583b18a?ref=imdb_web&autoplay=1&ref_=imdbref_ttep_mwbr_fdv&tag=imdbtag_ttep_mwbr_fdv-20)
# </p>
#
# <p>Enjoy the game !</p>

# %%
"""
Author: Alliyah Thompson
Source: Rogers, J., Downey, C., Boylan, C., (Writers). Millicent, S. (Director). (2010, Aug, 29). 
The King George Job (Season 3, Episode 12) [TV series episode]

DocString:
The following game is based on the Leverage television series from season three episode twelve. 
The purpose of this game is to use strategic thinking to help the leverage team stop John Keller 
and Damien Moreau from continuing their criminal activity. In this game, John Keller is an international antiquities trafficker who uses children as mules to smuggle antiquities. 
Our goal is to stop him and to help the young child that was arrested because of his criminal activity. 

* Level 1: Boston Airport (3 rounds)
* Level 2: Claridge's Auction House (2 rounds)
* Level 3: The Mummies Tiara (2 rounds)
* Level 4: London Airport (final round)

"""
#User input variable #
name = input(prompt = 'Insert your name: ')
print (f'Welcome {name}!')

print ("""
The rich and powerful take what they want. We steal it back for you. 
Sometimes, bad guys make the best good guys. 
""")
print("""
********************************************************************************************
We provide. Leverage. 
********************************************************************************************
""")


# Constructing level 1 and starting the game #
    
print("""Help our team stop an antiquities trafficker who is using children
as mules to smuggle artifacts into the U.S.\n """)

input('<Press ENTER to continue to LEVEL 1>.\n')
    
print ("""
At the airport, you see John Keller who works for our primary target Damien Moreau. 
However, he has no checked luggage just a carry-on. 

Based on the arrival flight you believe he is carrying Iranian antiquities. 
You are a Customs & Border Control Agent, and Mr. Keller is next in line to 
be interviewed. 

********************************************************************************************
""")

    
def level_1(): # This is the beginning of the game - Boston Airport #
    #user variable #
    interview_q1 = input(prompt = """
    \033[1m Which of the following do you select?\033[0;0m 
        1.  Interview Keller yourself 
        2.  Listen in on the conversation with the next agent
    """).capitalize()

    # Decision 1 input - condition statement #
    if '1' in interview_q1 or 'Interview' in interview_q1 or 'Keller' in interview_q1 or 'yourself' in interview_q1 or 'a' in interview_q1:
        print("""
    \033[1m Result:\033[0;0mYou begin to ask him some questions, but nothing suspicious occurs. 
            While answering the last question a siren goes off, saying code 4, security 
            to customs. \n
         """)
    elif '2' in interview_q1 or 'Listen' in interview_q1 or 'the conversation'in interview_q1 or 'next agent'in interview_q1  or 'b' in interview_q1:
        print("""
    \033[1m Result:\033[0;0m Keller states that he is visiting Boston for a business meeting and is only 
            staying 24 hours. While answering the last question a siren goes off, saying code 4, 
            security to customs.\033[0;0m \n
        """)
    else:
        print('Invalid entry.')
        input (prompt = 'Try again')
level_1() # Brings you back to round 1 - level 1 to try again

print('_________________________________________________________________________________________')


# Round 2 - Level 1 #
def q_2():
    
#user input # 
    
#user input #
    gender = input(f"""
\033[1m Please enter a gender:\033[0;0m
    Pick between a boy or girl
    \n
    """).capitalize()

    if 'girl' in gender or 'g' in gender or 'female' in gender or 'women' in gender:
        print(f"""
    \033[1m Result:\033[0;0m A little \033[1m {gender} \033[0;0m is arrested for smuggling and brought in for question as 
            an antique is found in their bag. The child doesn’t speak English and begins to cry for there family
            as they only speak Arabic. 
            """)
    elif 'boy' in gender or 'b' in gender or 'male' in gender or 'man': 
        print(f"""
    \033[1m Result:\033[0;0m A little \033[1m {gender} \033[0;0m is arrested for smuggling and brought in for question as an 
            antique is found in their bag. The child doesn’t speak English and begins to cry for there family
            as they only speak Arabic.
            """)
    else: 
        print('Invalid entry.')
        input (prompt = 'Try again')
q_2() # Brings you back to round 2 - level 1 to try again
        
# Question 3 # 
def q_3():
        # Round 3 - Level 1 #
    print("""
    John Keller – who is believed to be a smuggler is released from customs and walks away while the 
    young child is carried away. 
    """)

#user variable #
    selection = input (prompt = """
    \033[1m Do you want to send another member of your team to follow him? \033[0;0m 
    1.  Yes
    2.  No 
    """).capitalize().lower()

#developing condition statements #
    if 'yes' in selection or 'y' in selection or '1' in selection:
        print("""
    \033[1m Result:\033[0;0m Oh no!,you follow him outside of the airport and he turns into the corner of the exist
              and his bodyguard beats you until your unconscious. \n 
              """)
    elif 'no' in selection or 'n'in selection or '2'in selection:
        print("""
    \033[1m Result:\033[0;0m You regroup as a team to find out how the little girl is doing and create a new plan 
            to get the child out of jail and catch Keller. \n 
            """)
    else:
        print ('Invalid entry.')
        input (prompt = 'Try again')
q_3() # Brings you back to round 3 - level 1 to try again

print('________________________________________________________________________________________________')
    
def level_2(): # This is the beginning of level 2 - Claridge's Auction House #
    input('<Press ENTER to continue to LEVEL 2>.\n')

print ("""
YOU HAVE NOW ENTERED LEVEL 2!

You and your team fly to London where John Keller is scheduled to appear at the Claridge's 
auction house.\n
""")
    
print("""
You find the administration office, where the filing system and computers are located. However, you realize 
the system is your old because of the history of the auction house. \n
""")

#user input variable
search = input (prompt = """
\033[1m Do you search the filing cabinet for Keller’s name or wait for the old system to load and try to search his name? \033[0;0m 
1.  Wait for system
2.  Manual search 
""").capitalize()

#developing condition statements #
if 'wait for system' in search or '1' in search:
    print("""
\033[1m Result:\033[0;0m Oh no!,you lost 10  minutes waiting for the computer system.\n 
          """)
elif 'manual search' in search or '2' in search:
    print("""
\033[1m Result:\033[0;0m You find two files with Keller’s name, one with all his sales, and fake provenances. \n 
        """)
else:
    print ('Invalid entry.')
level_2() # Brings you back to round 1 - level 2 to try again

print('____________________________________________________________________________________')
# Round 2 - Level 2 #       
def q_4():
    #user variable ) 
    footsteps = input (prompt = """
    \033[1m You hear footsteps near the door, you only have time to search one file, which one do you choose? \033[0;0m 
    1.  Smaller file
    2.  Larger file
    """).capitalize()
    
#developing condition statements #
    if 'smaller file' in footsteps or '1' in footsteps :
        print("""
        \033[1m Result:\033[0;0m The smaller file has all his land purchases of properties in Scotland. Based on the file you learn 
            about Keller’s desire for royal pieces and rare artifacts for personal collection through his purchases.
        
            After learning this, one of your team members persuades him to help them smuggle an item into the 
            U.S in exchange for one of the lost baronies.\n 
              """)
    elif 'larger file' in footsteps or '2' in footsteps:
        print("""
        \033[1m Result:\033[0;0m You find two files with Keller’s name, one with all his sales, and fake provenances. 
        
            Your team leaves the auction house and decides to gather more research to develop a plan and reconnect 
            with Keller.\n 
            """)
    else:
        print ('Invalid entry.')
q_4() # Brings you back to round 1 - level 2 to try again
# Out:
# Insert your name: Kay
# Welcome Kay!
#
# The rich and powerful take what they want. We steal it back for you.
# Sometimes, bad guys make the best good guys.
#
#
# ********************************************************************************************
# We provide. Leverage.
# ********************************************************************************************
#
# Help our team stop an antiquities trafficker who is using children
# as mules to smuggle artifacts into the U.S.
#
# <Press ENTER to continue to LEVEL 1>.
#
#
# At the airport, you see John Keller who works for our primary target Damien Moreau.
# However, he has no checked luggage just a carry-on.
#
# Based on the arrival flight you believe he is carrying Iranian antiquities.
# You are a Customs & Border Control Agent, and Mr. Keller is next in line to
# be interviewed.
#
# ********************************************************************************************
#
#
# ...
